# %%
from bs4 import BeautifulSoup
def es_multiplo(numero, multiplo):
    if numero % multiplo == 0:
        return True
    else:
        return False
    
def changeCaracter(value, string):
    index = 77
    new_character = value
    string = string[:index] + new_character + string[index+1:]
    return string

# %%
def helpScroll(x,driver):
        x = x-4
        sx = str(x)
        txt1 = changeCaracter(sx,txt)
        print('scroll',txt1)
        python = driver.find_element(By.XPATH, txt1)
        driver.execute_script('arguments[0].scrollIntoView(true)',python)
        time.sleep(5)
        
        x = x+2
        sx = str(x)
        txt1 = changeCaracter(sx,txt)
        print('scroll',txt1)
        python = driver.find_element(By.XPATH, txt1)
        driver.execute_script('arguments[0].scrollIntoView(true)',python)
        time.sleep(5)
        
        x = x-2
        sx = str(x)
        txt1 = changeCaracter(sx,txt)
        print('scroll',txt1)
        python = driver.find_element(By.XPATH, txt1)
        driver.execute_script('arguments[0].scrollIntoView(true)',python)
        time.sleep(5)
        
        x = x+2
        sx = str(x)
        txt1 = changeCaracter(sx,txt)
        print('scroll',txt1)
        python = driver.find_element(By.XPATH, txt1)
        driver.execute_script('arguments[0].scrollIntoView(true)',python)
        time.sleep(5)
        
        
        x = x-2
        return x

# %%
def downScroll(x,driver): 
        x = x+2
        sx = str(x)
        txt1 = changeCaracter(sx,txt)
        print('scroll',txt1)
        python = driver.find_element(By.XPATH, txt1)
        driver.execute_script('arguments[0].scrollIntoView(true)',python)
        time.sleep(25)    
        x = x-2
        return x

# %%
def extractdata(driver,listNames,listAverage,listAbout,listReview,listDir,listEmail,listPhone,info):
    page_content = driver.page_source
    soup = BeautifulSoup(page_content, 'html.parser')
    names = soup.find("h1", class_= "DUwDvf")
    lugares = soup.find_all("div", class_= "Io6YTe")
    typeB = soup.find("button", class_= "DkEaL")
    block = soup.find_all("div", class_= "F7nice")
    count = 0
    name = ''
    star = 0
    data = ''
    value = []
    if(len(names)==5):
        for search in names:
            if(count == 1):
                name = search.string
            count = count + 1
        count = 0
        try:
            listNames.index(name)
            print("Repeat",name)
            print("it does not save")
        except:
            listNames.append(name)
            listAbout.append(typeB.string)
            for search in block:
                i = search.find_all("span")
                for re in i:
                    if(re.string != None):
                        count = count + 1
                        if(count == 1):
                            star = re.string
                            listAverage.append(star)
                        if(count == 2):
                            data = re.string
                            listReview.append(data)
            count = 0
            for search in lugares:
                if(search.string != None):
                    value.append(search.string)
                    if(count==0):
                        listDir.append(search.string) 
                    if(count==4):
                        listEmail.append(search.string) 
                    if(count==5):
                        listPhone.append(search.string) 
                    count = count + 1
            info.append(value)
            print("-------------------------------------------------------------------------------------------------------")
            print(name)
            #print(star)
            #print(typeB.string)
            #print(data)
            #print(value)
            print("-------------------------------------------------------------------------------------------------------")

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time
driver = webdriver.Chrome()
driver.get("https://www.google.com/maps/search/bares+ny/@40.7443439,-74.0197995,13z")
time.sleep(2)
txt =  '//*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[1]/div/a'

listNames = []
listAverage = []
listAbout = []
listReview = []
listDir = []
listEmail = []
listPhone = []
info = []

x = 1
j = 1
count = 1
t = 5
value = 90
for i in range(value):
    x = x+2
    sx = str(x)
    txt1 = changeCaracter(sx,txt)
    output = es_multiplo(i+1,5)
    if(output):
        try:
            print("count  without click",count)
            n = x-2
            sn = str(n)
            ant = changeCaracter(sn,txt)
            print('scroll',ant)
            python = driver.find_element(By.XPATH, ant)
            driver.execute_script('arguments[0].scrollIntoView(true)',python)
            time.sleep(3)
            print('scroll',txt1)
            python = driver.find_element(By.XPATH, txt1)
            driver.execute_script('arguments[0].scrollIntoView(true)',python)
            time.sleep(3)
            x = x-2
        except:
            try:
                print("FIX-0·································································")
                x = downScroll(x,driver)
                print("FIX-0·································································")
            except:
                print("FIX-1$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$")
                x =  helpScroll(x,driver)
                print("FIX-1$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$")
            
    else:
        print("Count %s, %s" % (count, txt1))
        try:
            driver.find_element(By.XPATH, txt1 ).click()
            time.sleep(10)
            count = count + 1
        except:
            print("FIX-2*******************************************************************************")
            x = helpScroll(x,driver)
            print("FIX-2*******************************************************************************")
            
        extractdata(driver,listNames,listAverage,listAbout,listReview,listDir,listEmail,listPhone,info)
print('end script')
# Out:
# Count 1, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[3]/div/a
# -------------------------------------------------------------------------------------------------------
# Charlie Bird
# -------------------------------------------------------------------------------------------------------
# Count 2, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[5]/div/a
# -------------------------------------------------------------------------------------------------------
# Chorus Karaoke
# -------------------------------------------------------------------------------------------------------
# Count 3, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[7]/div/a
# -------------------------------------------------------------------------------------------------------
# Bar 54
# -------------------------------------------------------------------------------------------------------
# Count 4, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[9]/div/a
# -------------------------------------------------------------------------------------------------------
# Rudy's Bar & Grill
# -------------------------------------------------------------------------------------------------------
# count  without click 5
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[9]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[11]/div/a
# Count 5, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[11]/div/a
# -------------------------------------------------------------------------------------------------------
# Barcelona Bar
# -------------------------------------------------------------------------------------------------------
# Count 6, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[13]/div/a
# -------------------------------------------------------------------------------------------------------
# The Dead Rabbit
# -------------------------------------------------------------------------------------------------------
# Count 7, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[15]/div/a
# -------------------------------------------------------------------------------------------------------
# Clandestino
# -------------------------------------------------------------------------------------------------------
# Count 8, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[17]/div/a
# -------------------------------------------------------------------------------------------------------
# Blue Ruin Bar
# -------------------------------------------------------------------------------------------------------
# count  without click 9
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[17]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[19]/div/a
# Count 9, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[19]/div/a
# -------------------------------------------------------------------------------------------------------
# The Rum House
# -------------------------------------------------------------------------------------------------------
# Count 10, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[21]/div/a
# -------------------------------------------------------------------------------------------------------
# Johnny's Bar
# -------------------------------------------------------------------------------------------------------
# Count 11, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[23]/div/a
# -------------------------------------------------------------------------------------------------------
# 230 Fifth
# -------------------------------------------------------------------------------------------------------
# Count 12, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[25]/div/a
# -------------------------------------------------------------------------------------------------------
# Pocket Bar NYC
# -------------------------------------------------------------------------------------------------------
# count  without click 13
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[25]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[27]/div/a
# FIX-0·································································
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[29]/div/a
# FIX-1$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[23]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[25]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[23]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[25]/div/a
# FIX-1$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# Count 13, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[25]/div/a
# Repeat Pocket Bar NYC
# it does not save
# Count 14, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[27]/div/a
# FIX-2*******************************************************************************
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[23]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[25]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[23]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[25]/div/a
# FIX-2*******************************************************************************
# Repeat Pocket Bar NYC
# it does not save
# Count 14, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[25]/div/a
# Repeat Pocket Bar NYC
# it does not save
# Count 15, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[27]/div/a
# Repeat Pocket Bar NYC
# it does not save
# count  without click 16
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[27]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[29]/div/a
# Count 16, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[29]/div/a
# Repeat Pocket Bar NYC
# it does not save
# Count 17, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[31]/div/a
# Repeat Pocket Bar NYC
# it does not save
# Count 18, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# Repeat Pocket Bar NYC
# it does not save
# Count 19, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[35]/div/a
# FIX-2*******************************************************************************
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[31]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[31]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# FIX-2*******************************************************************************
# Repeat Pocket Bar NYC
# it does not save
# count  without click 19
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[31]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# Count 19, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# Repeat Pocket Bar NYC
# it does not save
# Count 20, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[35]/div/a
# FIX-2*******************************************************************************
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[31]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[31]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# FIX-2*******************************************************************************
# Repeat Pocket Bar NYC
# it does not save
# Count 20, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# Repeat Pocket Bar NYC
# it does not save
# Count 21, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[35]/div/a
# FIX-2*******************************************************************************
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[31]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[31]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# FIX-2*******************************************************************************
# Repeat Pocket Bar NYC
# it does not save
# count  without click 21
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[31]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# Count 21, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# Repeat Pocket Bar NYC
# it does not save
# Count 22, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[35]/div/a
# FIX-2*******************************************************************************
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[31]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[31]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# FIX-2*******************************************************************************
# Repeat Pocket Bar NYC
# it does not save
# Count 22, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# Repeat Pocket Bar NYC
# it does not save
# Count 23, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[35]/div/a
# FIX-2*******************************************************************************
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[31]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[31]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# FIX-2*******************************************************************************
# Repeat Pocket Bar NYC
# it does not save
# count  without click 23
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[31]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# Count 23, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# Repeat Pocket Bar NYC
# it does not save
# Count 24, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[35]/div/a
# FIX-2*******************************************************************************
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[31]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[31]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# FIX-2*******************************************************************************
# Repeat Pocket Bar NYC
# it does not save
# Count 24, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# Repeat Pocket Bar NYC
# it does not save
# Count 25, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[35]/div/a
# FIX-2*******************************************************************************
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[31]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[31]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# FIX-2*******************************************************************************
# Repeat Pocket Bar NYC
# it does not save
# count  without click 25
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[31]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# Count 25, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# Repeat Pocket Bar NYC
# it does not save
# Count 26, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[35]/div/a
# FIX-2*******************************************************************************
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[31]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[31]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# FIX-2*******************************************************************************
# Repeat Pocket Bar NYC
# it does not save
# Count 26, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# Repeat Pocket Bar NYC
# it does not save
# Count 27, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[35]/div/a
# FIX-2*******************************************************************************
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[31]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[31]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# FIX-2*******************************************************************************
# Repeat Pocket Bar NYC
# it does not save
# count  without click 27
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[31]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# Count 27, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# Repeat Pocket Bar NYC
# it does not save
# Count 28, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[35]/div/a
# FIX-2*******************************************************************************
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[31]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[31]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# FIX-2*******************************************************************************
# Repeat Pocket Bar NYC
# it does not save
# Count 28, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# Repeat Pocket Bar NYC
# it does not save
# Count 29, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[35]/div/a
# FIX-2*******************************************************************************
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[31]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[31]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# FIX-2*******************************************************************************
# Repeat Pocket Bar NYC
# it does not save
# count  without click 29
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[31]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# Count 29, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# Repeat Pocket Bar NYC
# it does not save
# Count 30, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[35]/div/a
# FIX-2*******************************************************************************
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[31]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[31]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# FIX-2*******************************************************************************
# Repeat Pocket Bar NYC
# it does not save
# Count 30, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# Repeat Pocket Bar NYC
# it does not save
# Count 31, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[35]/div/a
# FIX-2*******************************************************************************
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[31]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[31]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# FIX-2*******************************************************************************
# Repeat Pocket Bar NYC
# it does not save
# count  without click 31
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[31]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# Count 31, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# Repeat Pocket Bar NYC
# it does not save
# Count 32, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[35]/div/a
# FIX-2*******************************************************************************
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[31]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[31]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# FIX-2*******************************************************************************
# Repeat Pocket Bar NYC
# it does not save
# Count 32, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# Repeat Pocket Bar NYC
# it does not save
# Count 33, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[35]/div/a
# FIX-2*******************************************************************************
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[31]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[31]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# FIX-2*******************************************************************************
# Repeat Pocket Bar NYC
# it does not save
# count  without click 33
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[31]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# Count 33, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# Repeat Pocket Bar NYC
# it does not save
# Count 34, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[35]/div/a
# FIX-2*******************************************************************************
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[31]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[31]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# FIX-2*******************************************************************************
# Repeat Pocket Bar NYC
# it does not save
# Count 34, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# Repeat Pocket Bar NYC
# it does not save
# Count 35, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[35]/div/a
# FIX-2*******************************************************************************
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[31]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[31]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# FIX-2*******************************************************************************
# -------------------------------------------------------------------------------------------------------
# S Bar
# -------------------------------------------------------------------------------------------------------
# count  without click 35
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[31]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# Count 35, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# Repeat S Bar
# it does not save
# Count 36, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[35]/div/a
# -------------------------------------------------------------------------------------------------------
# Strangelove Bar Nyc
# -------------------------------------------------------------------------------------------------------
# Count 37, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[37]/div/a
# -------------------------------------------------------------------------------------------------------
# St. Pat's Bar & Grill NYC
# -------------------------------------------------------------------------------------------------------
# Count 38, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[39]/div/a
# -------------------------------------------------------------------------------------------------------
# Bar Nine
# -------------------------------------------------------------------------------------------------------
# count  without click 39
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[39]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[41]/div/a
# Count 39, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[41]/div/a
# -------------------------------------------------------------------------------------------------------
# Fools Gold NYC
# -------------------------------------------------------------------------------------------------------
# Count 40, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[43]/div/a
# -------------------------------------------------------------------------------------------------------
# High Bar New York
# -------------------------------------------------------------------------------------------------------
# Count 41, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[45]/div/a
# -------------------------------------------------------------------------------------------------------
# Iron Bar & Lounge
# -------------------------------------------------------------------------------------------------------
# Count 42, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[47]/div/a
# FIX-2*******************************************************************************
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[43]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[45]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[43]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[45]/div/a
# FIX-2*******************************************************************************
# Repeat Iron Bar & Lounge
# it does not save
# count  without click 42
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[43]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[45]/div/a
# Count 42, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[45]/div/a
# Repeat Iron Bar & Lounge
# it does not save
# Count 43, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[47]/div/a
# FIX-2*******************************************************************************
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[43]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[45]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[43]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[45]/div/a
# FIX-2*******************************************************************************
# Repeat Iron Bar & Lounge
# it does not save
# Count 43, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[45]/div/a
# Repeat Iron Bar & Lounge
# it does not save
# Count 44, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[47]/div/a
# FIX-2*******************************************************************************
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[43]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[45]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[43]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[45]/div/a
# FIX-2*******************************************************************************
# Repeat Iron Bar & Lounge
# it does not save
# count  without click 44
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[43]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[45]/div/a
# Count 44, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[45]/div/a
# Repeat Iron Bar & Lounge
# it does not save
# Count 45, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[47]/div/a
# FIX-2*******************************************************************************
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[43]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[45]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[43]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[45]/div/a
# FIX-2*******************************************************************************
# Repeat Iron Bar & Lounge
# it does not save
# Count 45, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[45]/div/a
# Repeat Iron Bar & Lounge
# it does not save
# Count 46, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[47]/div/a
# FIX-2*******************************************************************************
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[43]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[45]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[43]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[45]/div/a
# FIX-2*******************************************************************************
# Repeat Iron Bar & Lounge
# it does not save
# count  without click 46
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[43]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[45]/div/a
# Count 46, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[45]/div/a
# Repeat Iron Bar & Lounge
# it does not save
# Count 47, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[47]/div/a
# Repeat Iron Bar & Lounge
# it does not save
# Count 48, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[49]/div/a
# Repeat Iron Bar & Lounge
# it does not save
# Count 49, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[51]/div/a
# Repeat Iron Bar & Lounge
# it does not save
# count  without click 50
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[51]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[53]/div/a
# end script

# %%
print(len(listNames))
print(len(listAverage))
print(len(listAbout))
print(len(listReview))
print(len(info))
# Out:
# 19
# 19
# 19
# 19
# 19

# %%
import pandas as pd
col1 = "Nombres"
col2 = "Promedio"
col3 = "Tipo"
col4 = "Reseñas"
col5 = "info"
data = pd.DataFrame({col1:listNames,col2:listAverage,col3:listAbout,col4:listReview,col5:info})
data.to_excel('sample_data.xlsx', sheet_name='sheet1', index=False)
