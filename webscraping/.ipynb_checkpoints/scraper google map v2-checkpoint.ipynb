# %%
from bs4 import BeautifulSoup
def es_multiplo(numero, multiplo):
    if numero % multiplo == 0:
        return True
    else:
        return False
    
def changeCaracter(value, string):
    index = 77
    new_character = value
    string = string[:index] + new_character + string[index+1:]
    return string

# %%
def helpScroll(x,driver):
        x = x-4
        sx = str(x)
        txt1 = changeCaracter(sx,txt)
        print('scroll',txt1)
        python = driver.find_element(By.XPATH, txt1)
        driver.execute_script('arguments[0].scrollIntoView(true)',python)
        time.sleep(5)
        
        x = x+2
        sx = str(x)
        txt1 = changeCaracter(sx,txt)
        print('scroll',txt1)
        python = driver.find_element(By.XPATH, txt1)
        driver.execute_script('arguments[0].scrollIntoView(true)',python)
        time.sleep(5)
        
        x = x-2
        sx = str(x)
        txt1 = changeCaracter(sx,txt)
        print('scroll',txt1)
        python = driver.find_element(By.XPATH, txt1)
        driver.execute_script('arguments[0].scrollIntoView(true)',python)
        time.sleep(5)
        
        x = x+2
        sx = str(x)
        txt1 = changeCaracter(sx,txt)
        print('scroll',txt1)
        python = driver.find_element(By.XPATH, txt1)
        driver.execute_script('arguments[0].scrollIntoView(true)',python)
        time.sleep(5)
        
        
        x = x-2
        return x

# %%
def downScroll(x,driver): 
        x = x+2
        sx = str(x)
        txt1 = changeCaracter(sx,txt)
        print('scroll',txt1)
        python = driver.find_element(By.XPATH, txt1)
        driver.execute_script('arguments[0].scrollIntoView(true)',python)
        time.sleep(25)    
        x = x-2
        return x

# %%
def extractdata(driver,listNames,listAverage,listAbout,listReview,listDir,listEmail,listPhone,info):
    page_content = driver.page_source
    soup = BeautifulSoup(page_content, 'html.parser')
    names = soup.find("h1", class_= "DUwDvf")
    lugares = soup.find_all("div", class_= "Io6YTe")
    typeB = soup.find("button", class_= "DkEaL")
    block = soup.find_all("div", class_= "F7nice")
    count = 0
    name = ''
    star = 0
    data = ''
    value = []
    if(len(names)==5):
        for search in names:
            if(count == 1):
                name = search.string
            count = count + 1
        count = 0
        try:
            listNames.index(name)
            print("Repeat",name)
            print("it does not save")
        except:
            listNames.append(name)
            listAbout.append(typeB.string)
            for search in block:
                i = search.find_all("span")
                for re in i:
                    if(re.string != None):
                        count = count + 1
                        if(count == 1):
                            star = re.string
                            listAverage.append(star)
                        if(count == 2):
                            data = re.string
                            listReview.append(data)
            count = 0
            for search in lugares:
                if(search.string != None):
                    value.append(search.string)
                    if(count==0):
                        listDir.append(search.string) 
                    if(count==4):
                        listEmail.append(search.string) 
                    if(count==5):
                        listPhone.append(search.string) 
                    count = count + 1
            info.append(value)
            print("-------------------------------------------------------------------------------------------------------")
            print(name)
            #print(star)
            #print(typeB.string)
            #print(data)
            #print(value)
            print("-------------------------------------------------------------------------------------------------------")

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time
driver = webdriver.Chrome()
driver.get("https://www.google.com/maps/search/bares+ny/@40.7443439,-74.0197995,13z")
time.sleep(2)
txt =  '//*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[1]/div/a'

listNames = []
listAverage = []
listAbout = []
listReview = []
listDir = []
listEmail = []
listPhone = []
info = []

x = 1
j = 1
count = 1
t = 5
value = 90
for i in range(value):
    x = x+2
    sx = str(x)
    txt1 = changeCaracter(sx,txt)
    output = es_multiplo(i+1,5)
    if(output):
        try:
            print("count  without click",count)
            n = x-2
            sn = str(n)
            ant = changeCaracter(sn,txt)
            print('scroll',ant)
            python = driver.find_element(By.XPATH, ant)
            driver.execute_script('arguments[0].scrollIntoView(true)',python)
            time.sleep(3)
            print('scroll',txt1)
            python = driver.find_element(By.XPATH, txt1)
            driver.execute_script('arguments[0].scrollIntoView(true)',python)
            time.sleep(3)
            x = x-2
        except:
            try:
                print("FIX-0·································································")
                x = downScroll(x,driver)
                print("FIX-0·································································")
            except:
                print("FIX-1$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$")
                x =  helpScroll(x,driver)
                print("FIX-1$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$")
            
    else:
        print("Count %s, %s" % (count, txt1))
        try:
            driver.find_element(By.XPATH, txt1 ).click()
            time.sleep(10)
            count = count + 1
        except:
            print("FIX-2*******************************************************************************")
            x = helpScroll(x,driver)
            print("FIX-2*******************************************************************************")
            
        extractdata(driver,listNames,listAverage,listAbout,listReview,listDir,listEmail,listPhone,info)
print('end script')
# Out:
# count 1
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[3]/div/a
# -------------------------------------------------------------------------------------------------------
# Charlie Bird
# -------------------------------------------------------------------------------------------------------
# count 2
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[5]/div/a
# -------------------------------------------------------------------------------------------------------
# Dave & Buster's New York City - Times Square
# -------------------------------------------------------------------------------------------------------
# count 3
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[7]/div/a
# -------------------------------------------------------------------------------------------------------
# Bar 54
# -------------------------------------------------------------------------------------------------------
# count 4
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[9]/div/a
# -------------------------------------------------------------------------------------------------------
# Rudy's Bar & Grill
# -------------------------------------------------------------------------------------------------------
# count  without click 5
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[9]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[11]/div/a
# count 5
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[11]/div/a
# -------------------------------------------------------------------------------------------------------
# Barcelona Bar
# -------------------------------------------------------------------------------------------------------
# count 6
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[13]/div/a
# -------------------------------------------------------------------------------------------------------
# The Dead Rabbit
# -------------------------------------------------------------------------------------------------------
# count 7
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[15]/div/a
# -------------------------------------------------------------------------------------------------------
# Clandestino
# -------------------------------------------------------------------------------------------------------
# count 8
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[17]/div/a
# -------------------------------------------------------------------------------------------------------
# The Rum House
# -------------------------------------------------------------------------------------------------------
# count  without click 9
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[17]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[19]/div/a
# count 9
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[19]/div/a
# -------------------------------------------------------------------------------------------------------
# Johnny's Bar
# -------------------------------------------------------------------------------------------------------
# count 10
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[21]/div/a
# -------------------------------------------------------------------------------------------------------
# Pocket Bar NYC
# -------------------------------------------------------------------------------------------------------
# count 11
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[23]/div/a
# -------------------------------------------------------------------------------------------------------
# 230 Fifth
# -------------------------------------------------------------------------------------------------------
# count 12
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[25]/div/a
# -------------------------------------------------------------------------------------------------------
# McSorley’s Old Ale House
# -------------------------------------------------------------------------------------------------------
# count  without click 13
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[25]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[27]/div/a
# count 13
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[27]/div/a
# -------------------------------------------------------------------------------------------------------
# Solo Empleados
# -------------------------------------------------------------------------------------------------------
# count 14
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[29]/div/a
# -------------------------------------------------------------------------------------------------------
# S Bar
# -------------------------------------------------------------------------------------------------------
# count 15
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[31]/div/a
# -------------------------------------------------------------------------------------------------------
# Old Town Bar
# -------------------------------------------------------------------------------------------------------
# count 16
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# -------------------------------------------------------------------------------------------------------
# Strangelove Bar Nyc
# -------------------------------------------------------------------------------------------------------
# count  without click 17
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[35]/div/a
# count 17
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[35]/div/a
# -------------------------------------------------------------------------------------------------------
# Fools Gold NYC
# -------------------------------------------------------------------------------------------------------
# count 18
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[37]/div/a
# -------------------------------------------------------------------------------------------------------
# St. Pat's Bar & Grill NYC
# -------------------------------------------------------------------------------------------------------
# count 19
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[39]/div/a
# -------------------------------------------------------------------------------------------------------
# Smith's Bar
# -------------------------------------------------------------------------------------------------------
# count 20
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[41]/div/a
# fix2-*******************************************************************************
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[37]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[39]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[37]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[39]/div/a
# fix2-*******************************************************************************
# Repeat Smith's Bar
# it does not save
# count  without click 20
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[37]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[39]/div/a
# count 20
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[39]/div/a
# Repeat Smith's Bar
# it does not save
# count 21
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[41]/div/a
# -------------------------------------------------------------------------------------------------------
# High Bar New York
# -------------------------------------------------------------------------------------------------------
# count 22
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[43]/div/a
# -------------------------------------------------------------------------------------------------------
# Iron Bar & Lounge
# -------------------------------------------------------------------------------------------------------
# count 23
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[45]/div/a
# -------------------------------------------------------------------------------------------------------
# Nassau Bar
# -------------------------------------------------------------------------------------------------------
# count  without click 24
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[45]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[47]/div/a
# fix-0····································································
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[49]/div/a
# fix1-$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[43]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[45]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[43]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[45]/div/a
# fix1-$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# count 24
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[45]/div/a
# Repeat Nassau Bar
# it does not save
# count 25
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[47]/div/a
# fix2-*******************************************************************************
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[43]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[45]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[43]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[45]/div/a
# fix2-*******************************************************************************
# Repeat Nassau Bar
# it does not save
# count 25
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[45]/div/a
# Repeat Nassau Bar
# it does not save
# count 26
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[47]/div/a
# fix2-*******************************************************************************
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[43]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[45]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[43]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[45]/div/a
# fix2-*******************************************************************************
# Repeat Nassau Bar
# it does not save
# count  without click 26
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[43]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[45]/div/a
# count 26
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[45]/div/a
# Repeat Nassau Bar
# it does not save
# count 27
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[47]/div/a
# fix2-*******************************************************************************
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[43]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[45]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[43]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[45]/div/a
# fix2-*******************************************************************************
# Repeat Nassau Bar
# it does not save
# count 27
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[45]/div/a
# Repeat Nassau Bar
# it does not save
# count 28
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[47]/div/a
# fix2-*******************************************************************************
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[43]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[45]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[43]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[45]/div/a
# fix2-*******************************************************************************
# Repeat Nassau Bar
# it does not save
# count  without click 28
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[43]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[45]/div/a
# count 28
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[45]/div/a
# Repeat Nassau Bar
# it does not save
# count 29
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[47]/div/a
# fix2-*******************************************************************************
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[43]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[45]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[43]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[45]/div/a
# fix2-*******************************************************************************
# Repeat Nassau Bar
# it does not save
# count 29
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[45]/div/a
# Repeat Nassau Bar
# it does not save
# count 30
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[47]/div/a
# fix2-*******************************************************************************
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[43]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[45]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[43]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[45]/div/a
# fix2-*******************************************************************************
# Repeat Nassau Bar
# it does not save
# count  without click 30
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[43]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[45]/div/a
# count 30
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[45]/div/a
# Repeat Nassau Bar
# it does not save
# count 31
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[47]/div/a
# fix2-*******************************************************************************
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[43]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[45]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[43]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[45]/div/a
# fix2-*******************************************************************************
# Repeat Nassau Bar
# it does not save
# count 31
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[45]/div/a
# Repeat Nassau Bar
# it does not save
# count 32
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[47]/div/a
# Repeat Nassau Bar
# it does not save
# count  without click 33
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[47]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[49]/div/a
# count 33
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[49]/div/a
# -------------------------------------------------------------------------------------------------------
# Temple Bar
# -------------------------------------------------------------------------------------------------------
# count 34
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[51]/div/a
# Repeat Temple Bar
# it does not save
# count 35
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[53]/div/a
# fix2-*******************************************************************************
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[49]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[51]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[49]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[51]/div/a
# fix2-*******************************************************************************
# Repeat Temple Bar
# it does not save
# count 35
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[51]/div/a
# -------------------------------------------------------------------------------------------------------
# The Pony Bar
# -------------------------------------------------------------------------------------------------------
# count  without click 36
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[51]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[53]/div/a
# count 36
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[53]/div/a
# Repeat The Pony Bar
# it does not save
# count 37
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[55]/div/a
# Repeat The Pony Bar
# it does not save
# count 38
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[57]/div/a
# Repeat The Pony Bar
# it does not save
# count 39
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[59]/div/a
# fix2-*******************************************************************************
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[55]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[57]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[55]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[57]/div/a
# fix2-*******************************************************************************
# Repeat The Pony Bar
# it does not save
# count  without click 39
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[55]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[57]/div/a
# count 39
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[57]/div/a
# Repeat The Pony Bar
# it does not save
# count 40
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[59]/div/a
# Repeat The Pony Bar
# it does not save
# count 41
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[61]/div/a
# Repeat The Pony Bar
# it does not save
# count 42
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[63]/div/a
# fix2-*******************************************************************************
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[59]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[61]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[59]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[61]/div/a
# fix2-*******************************************************************************
# Repeat The Pony Bar
# it does not save
# count  without click 42
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[59]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[61]/div/a
# count 42
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[61]/div/a
# Repeat The Pony Bar
# it does not save
# count 43
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[63]/div/a
# fix2-*******************************************************************************
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[59]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[61]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[59]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[61]/div/a
# fix2-*******************************************************************************
# Repeat The Pony Bar
# it does not save
# count 43
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[61]/div/a
# Repeat The Pony Bar
# it does not save
# count 44
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[63]/div/a
# fix2-*******************************************************************************
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[59]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[61]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[59]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[61]/div/a
# fix2-*******************************************************************************
# Repeat The Pony Bar
# it does not save
# count  without click 44
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[59]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[61]/div/a
# count 44
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[61]/div/a
# Repeat The Pony Bar
# it does not save
# count 45
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[63]/div/a
# fix2-*******************************************************************************
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[59]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[61]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[59]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[61]/div/a
# fix2-*******************************************************************************
# Repeat The Pony Bar
# it does not save
# count 45
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[61]/div/a
# -------------------------------------------------------------------------------------------------------
# The Townhouse of New York
# -------------------------------------------------------------------------------------------------------
# count 46
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[63]/div/a
# -------------------------------------------------------------------------------------------------------
# STITCH Bar & Blues
# -------------------------------------------------------------------------------------------------------
# count  without click 47
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[63]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[65]/div/a
# count 47
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[65]/div/a
# -------------------------------------------------------------------------------------------------------
# The Dakota Bar
# -------------------------------------------------------------------------------------------------------
# count 48
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[67]/div/a
# -------------------------------------------------------------------------------------------------------
# Juniper Bar
# -------------------------------------------------------------------------------------------------------
# count 49
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[69]/div/a
# fix2-*******************************************************************************
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[65]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[67]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[65]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[67]/div/a
# fix2-*******************************************************************************
# Repeat Juniper Bar
# it does not save
# count 49
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[67]/div/a
# Repeat Juniper Bar
# it does not save
# count  without click 50
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[67]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[69]/div/a
# count 50
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[69]/div/a
# Repeat Juniper Bar
# it does not save
# count 51
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[71]/div/a
# fix2-*******************************************************************************
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[67]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[69]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[67]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[69]/div/a
# fix2-*******************************************************************************
# -------------------------------------------------------------------------------------------------------
# BAR GOTO
# -------------------------------------------------------------------------------------------------------
# count 51
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[69]/div/a
# Repeat BAR GOTO
# it does not save
# count 52
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[71]/div/a
# -------------------------------------------------------------------------------------------------------
# The Bar Room
# -------------------------------------------------------------------------------------------------------
# count  without click 53
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[71]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[73]/div/a
# count 53
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[73]/div/a
# -------------------------------------------------------------------------------------------------------
# The Skinny Bar and Lounge
# -------------------------------------------------------------------------------------------------------
# count 54
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[75]/div/a
# -------------------------------------------------------------------------------------------------------
# Margarita Bar NYC
# -------------------------------------------------------------------------------------------------------
# count 55
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[77]/div/a
# -------------------------------------------------------------------------------------------------------
# Sean's Bar & Kitchen
# -------------------------------------------------------------------------------------------------------
# count 56
# click //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[79]/div/a
# fix2-*******************************************************************************
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[75]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[77]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[75]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[77]/div/a
# fix2-*******************************************************************************
# Repeat Sean's Bar & Kitchen
# it does not save
# count  without click 56
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[75]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[77]/div/a
# end script

# %%
print(len(listNames))
print(len(listAverage))
print(len(listAbout))
print(len(listReview))
print(len(info))
# Out:
# 33
# 33
# 72
# 33
# 33

# %%
import pandas as pd
col1 = "Nombres"
col2 = "Promedio"
col3 = "Tipo"
col4 = "Reseñas"
col5 = "info"
data = pd.DataFrame({col1:listNames,col2:listAverage,col3:listAbout,col4:listReview,col5:info})
data.to_excel('sample_data.xlsx', sheet_name='sheet1', index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_5804/3440261211.py in <module>
#       5 col4 = "Reseñas"
#       6 col5 = "info"
# ----> 7 data = pd.DataFrame({col1:listNames,col2:listAverage,col3:listAbout,col4:listReview,col5:info})
#       8 data.to_excel('sample_data.xlsx', sheet_name='sheet1', index=False)
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     634         elif isinstance(data, dict):
#     635             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637         elif isinstance(data, ma.MaskedArray):
#     638             import numpy.ma.mrecords as mrecords
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/internals/construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     500         # TODO: can we get rid of the dt64tz special case above?
#     501
# --> 502     return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#     503
#     504
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     118         # figure out the index, if necessary
#     119         if index is None:
# --> 120             index = _extract_index(arrays)
#     121         else:
#     122             index = ensure_index(index)
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/internals/construction.py in _extract_index(data)
#     672             lengths = list(set(raw_lengths))
#     673             if len(lengths) > 1:
# --> 674                 raise ValueError("All arrays must be of the same length")
#     675
#     676             if have_dicts:
#
# ValueError: All arrays must be of the same length
