# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time
import pandas as pd

def es_multiplo(numero, multiplo):
    if numero % multiplo == 0:
        return True
    else:
        return False
    
def changeCaracter(value, string):
    index = 77
    new_character = value
    string = string[:index] + new_character + string[index+1:]
    return string

def helpScroll(x,driver):
        x = x-4
        sx = str(x)
        txt1 = changeCaracter(sx,txt)
        print('scroll',txt1)
        python = driver.find_element(By.XPATH, txt1)
        driver.execute_script('arguments[0].scrollIntoView(true)',python)
        time.sleep(5)
        
        x = x+2
        sx = str(x)
        txt1 = changeCaracter(sx,txt)
        print('scroll',txt1)
        python = driver.find_element(By.XPATH, txt1)
        driver.execute_script('arguments[0].scrollIntoView(true)',python)
        time.sleep(5)
        
        x = x-2
        sx = str(x)
        txt1 = changeCaracter(sx,txt)
        print('scroll',txt1)
        python = driver.find_element(By.XPATH, txt1)
        driver.execute_script('arguments[0].scrollIntoView(true)',python)
        time.sleep(5)
        
        x = x+2
        sx = str(x)
        txt1 = changeCaracter(sx,txt)
        print('scroll',txt1)
        python = driver.find_element(By.XPATH, txt1)
        driver.execute_script('arguments[0].scrollIntoView(true)',python)
        time.sleep(5)
        
        
        x = x-2
        return x
def downScroll(x,driver): 
        x = x+2
        sx = str(x)
        txt1 = changeCaracter(sx,txt)
        print('scroll',txt1)
        python = driver.find_element(By.XPATH, txt1)
        driver.execute_script('arguments[0].scrollIntoView(true)',python)
        time.sleep(25)    
        x = x-2
        return x
def extractdata(driver,listNames,listAverage,listAbout,listReview,listDir,listEmail,listPhone,info):
    page_content = driver.page_source
    soup = BeautifulSoup(page_content, 'html.parser')
    names = soup.find("h1", class_= "DUwDvf")
    lugares = soup.find_all("div", class_= "Io6YTe")
    typeB = soup.find("button", class_= "DkEaL")
    block = soup.find_all("div", class_= "F7nice")
    count = 0
    name = ''
    star = 0
    data = ''
    value = []
    if(len(names)==5):
        for search in names:
            if(count == 1):
                name = search.string
            count = count + 1
        count = 0
        try:
            listNames.index(name)
            print("Repeat",name)
            print("it does not save")
        except:
            listNames.append(name)
            listAbout.append(typeB.string)
            for search in block:
                i = search.find_all("span")
                for re in i:
                    if(re.string != None):
                        count = count + 1
                        if(count == 1):
                            star = re.string
                            listAverage.append(star)
                        if(count == 2):
                            data = re.string
                            listReview.append(data)
            a=''
            b=''
            c=''
            listUrl =['.com', '.co', '.net', '.org', '.gob', '.es', '.info', '.me' ] 
            for search in lugares:
                if(search.string != None):
                    value.append(search.string)
                    dat=search.string
                    if(dat.find("+1") != -1):
                        a = dat
                        listPhone.append(dat)
                    if(dat.find("Estados Unidos") != -1):
                        b = dat
                        listDir.append(dat)
                    if(c==''):
                        for endUrl in listUrl:
                            if(dat.find(endUrl) != -1):
                                c = dat
                                listEmail.append(dat)
                                break
            if(a == ''):
                listPhone.append('')
            if(b == ''):
                listDir.append('')
            if(c == ''):
                listEmail.append('')
            info.append(value)
            print("-------------------------------------------------------------------------------------------------------")
            print(name)
            #print(star)
            #print(typeB.string)
            #print(data)
            #print(value)º
            print("-------------------------------------------------------------------------------------------------------")
            
driver = webdriver.Chrome()
url = input()
driver.get(url)
time.sleep(2)
txt =  '//*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[1]/div/a'

listNames = []
listAverage = []
listAbout = []
listReview = []
listDir = []
listEmail = []
listPhone = []
info = []

x = 1
j = 1
count = 1
t = 5
value = 1000
for i in range(value):
    x = x+2
    sx = str(x)
    txt1 = changeCaracter(sx,txt)
    output = es_multiplo(i+1,5)
    if(output):
        try:
            print("count  without click",count)
            n = x-2
            sn = str(n)
            ant = changeCaracter(sn,txt)
            print('scroll',ant)
            python = driver.find_element(By.XPATH, ant)
            driver.execute_script('arguments[0].scrollIntoView(true)',python)
            time.sleep(3)
            print('scroll',txt1)
            python = driver.find_element(By.XPATH, txt1)
            driver.execute_script('arguments[0].scrollIntoView(true)',python)
            time.sleep(3)
            x = x-2
        except:
            try:
                print("FIX-0·································································")
                x = downScroll(x,driver)
                print("FIX-0·································································")
            except:
                print("FIX-1$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$")
                x =  helpScroll(x,driver)
                print("FIX-1$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$")
            
    else:
        print("Count %s, %s" % (count, txt1))
        try:
            driver.find_element(By.XPATH, txt1 ).click()
            time.sleep(10)
            count = count + 1
        except:
            print("FIX-2*******************************************************************************")
            x = helpScroll(x,driver)
            print("FIX-2*******************************************************************************")
            
        extractdata(driver,listNames,listAverage,listAbout,listReview,listDir,listEmail,listPhone,info)
print('end script')

col1 = "Nombres"
col2 = "Promedio"
col3 = "Tipo"
col4 = "Reseñas"
col5 = "info"
data = pd.DataFrame({col1:listNames,col2:listAverage,col3:listAbout,col4:listReview,col5:info})
data.to_excel('a_data.xlsx', sheet_name='sheet1', index=False)

col1 = "Nombres"
col2 = "Promedio"
col3 = "Tipo"
col4 = "Reseñas"
col5 = "lugar"
col6 = "email"
col7 = "phone"
data = pd.DataFrame({col1:listNames,col2:listAverage,col3:listAbout,col4:listReview,col5:listDir,col6:listEmail,col7:listPhone})
data.to_excel('b_data.xlsx', sheet_name='sheet1', index=False)
# Out:
# https://www.google.com/maps/search/bar+ny/@40.7382196,-74.0239372,13z
# Count 1, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[3]/div/a
# -------------------------------------------------------------------------------------------------------
# Charlie Bird
# -------------------------------------------------------------------------------------------------------
# Count 2, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[5]/div/a
# -------------------------------------------------------------------------------------------------------
# Black Iron Burger
# -------------------------------------------------------------------------------------------------------
# Count 3, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[7]/div/a
# -------------------------------------------------------------------------------------------------------
# Fashion Bar
# -------------------------------------------------------------------------------------------------------
# Count 4, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[9]/div/a
# -------------------------------------------------------------------------------------------------------
# Rudy's Bar & Grill
# -------------------------------------------------------------------------------------------------------
# count  without click 5
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[9]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[11]/div/a
# FIX-0·································································
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[13]/div/a
# FIX-1$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[7]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[9]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[7]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[9]/div/a
# FIX-1$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# Count 5, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[9]/div/a
# Repeat Rudy's Bar & Grill
# it does not save
# Count 6, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[11]/div/a
# FIX-2*******************************************************************************
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[7]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[9]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[7]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[9]/div/a
# FIX-2*******************************************************************************
# Repeat Rudy's Bar & Grill
# it does not save
# Count 6, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[9]/div/a
# Repeat Rudy's Bar & Grill
# it does not save
# Count 7, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[11]/div/a
# FIX-2*******************************************************************************
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[7]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[9]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[7]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[9]/div/a
# FIX-2*******************************************************************************
# Repeat Rudy's Bar & Grill
# it does not save
# count  without click 7
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[7]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[9]/div/a
# Count 7, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[9]/div/a
# Repeat Rudy's Bar & Grill
# it does not save
# Count 8, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[11]/div/a
# FIX-2*******************************************************************************
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[7]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[9]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[7]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[9]/div/a
# FIX-2*******************************************************************************
# Repeat Rudy's Bar & Grill
# it does not save
# Count 8, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[9]/div/a
# Repeat Rudy's Bar & Grill
# it does not save
# Count 9, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[11]/div/a
# FIX-2*******************************************************************************
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[7]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[9]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[7]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[9]/div/a
# FIX-2*******************************************************************************
# Repeat Rudy's Bar & Grill
# it does not save
# count  without click 9
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[7]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[9]/div/a
# Count 9, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[9]/div/a
# Repeat Rudy's Bar & Grill
# it does not save
# Count 10, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[11]/div/a
# -------------------------------------------------------------------------------------------------------
# Johnny's Bar
# -------------------------------------------------------------------------------------------------------
# Count 11, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[13]/div/a
# Repeat Johnny's Bar
# it does not save
# Count 12, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[15]/div/a
# Repeat Johnny's Bar
# it does not save
# count  without click 13
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[15]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[17]/div/a
# Count 13, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[17]/div/a
# Repeat Johnny's Bar
# it does not save
# Count 14, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[19]/div/a
# FIX-2*******************************************************************************
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[15]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[17]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[15]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[17]/div/a
# FIX-2*******************************************************************************
# Repeat Johnny's Bar
# it does not save
# Count 14, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[17]/div/a
# Repeat Johnny's Bar
# it does not save
# Count 15, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[19]/div/a
# FIX-2*******************************************************************************
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[15]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[17]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[15]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[17]/div/a
# FIX-2*******************************************************************************
# -------------------------------------------------------------------------------------------------------
# John Sullivan's
# -------------------------------------------------------------------------------------------------------
# count  without click 15
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[15]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[17]/div/a
# Count 15, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[17]/div/a
# Repeat John Sullivan's
# it does not save
# Count 16, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[19]/div/a
# Repeat John Sullivan's
# it does not save
# Count 17, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[21]/div/a
# -------------------------------------------------------------------------------------------------------
# Local NYC
# -------------------------------------------------------------------------------------------------------
# Count 18, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[23]/div/a
# -------------------------------------------------------------------------------------------------------
# Snafu
# -------------------------------------------------------------------------------------------------------
# count  without click 19
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[23]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[25]/div/a
# Count 19, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[25]/div/a
# Repeat Snafu
# it does not save
# Count 20, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[27]/div/a
# -------------------------------------------------------------------------------------------------------
# 230 Fifth
# -------------------------------------------------------------------------------------------------------
# Count 21, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[29]/div/a
# -------------------------------------------------------------------------------------------------------
# Pocket Bar NYC
# -------------------------------------------------------------------------------------------------------
# Count 22, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[31]/div/a
# -------------------------------------------------------------------------------------------------------
# Nassau Bar
# -------------------------------------------------------------------------------------------------------
# count  without click 23
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[31]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# Count 23, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[33]/div/a
# -------------------------------------------------------------------------------------------------------
# Ty's Bar NYC
# -------------------------------------------------------------------------------------------------------
# Count 24, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[35]/div/a
# -------------------------------------------------------------------------------------------------------
# Faces and Names Bar & Lounge
# -------------------------------------------------------------------------------------------------------
# Count 25, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[37]/div/a
# Repeat Faces and Names Bar & Lounge
# it does not save
# Count 26, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[39]/div/a
# Repeat Faces and Names Bar & Lounge
# it does not save
# count  without click 27
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[39]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[41]/div/a
# Count 27, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[41]/div/a
# Repeat Faces and Names Bar & Lounge
# it does not save
# Count 28, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[43]/div/a
# FIX-2*******************************************************************************
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[39]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[41]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[39]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[41]/div/a
# FIX-2*******************************************************************************
# Repeat Faces and Names Bar & Lounge
# it does not save
# Count 28, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[41]/div/a
# Repeat Faces and Names Bar & Lounge
# it does not save
# Count 29, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[43]/div/a
# FIX-2*******************************************************************************
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[39]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[41]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[39]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[41]/div/a
# FIX-2*******************************************************************************
# Repeat Faces and Names Bar & Lounge
# it does not save
# count  without click 29
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[39]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[41]/div/a
# Count 29, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[41]/div/a
# Repeat Faces and Names Bar & Lounge
# it does not save
# Count 30, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[43]/div/a
# FIX-2*******************************************************************************
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[39]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[41]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[39]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[41]/div/a
# FIX-2*******************************************************************************
# Repeat Faces and Names Bar & Lounge
# it does not save
# Count 30, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[41]/div/a
# Repeat Faces and Names Bar & Lounge
# it does not save
# Count 31, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[43]/div/a
# FIX-2*******************************************************************************
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[39]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[41]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[39]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[41]/div/a
# FIX-2*******************************************************************************
# Repeat Faces and Names Bar & Lounge
# it does not save
# count  without click 31
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[39]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[41]/div/a
# Count 31, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[41]/div/a
# Repeat Faces and Names Bar & Lounge
# it does not save
# Count 32, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[43]/div/a
# FIX-2*******************************************************************************
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[39]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[41]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[39]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[41]/div/a
# FIX-2*******************************************************************************
# Repeat Faces and Names Bar & Lounge
# it does not save
# Count 32, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[41]/div/a
# Repeat Faces and Names Bar & Lounge
# it does not save
# Count 33, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[43]/div/a
# FIX-2*******************************************************************************
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[39]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[41]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[39]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[41]/div/a
# FIX-2*******************************************************************************
# Repeat Faces and Names Bar & Lounge
# it does not save
# count  without click 33
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[39]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[41]/div/a
# Count 33, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[41]/div/a
# Repeat Faces and Names Bar & Lounge
# it does not save
# Count 34, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[43]/div/a
# FIX-2*******************************************************************************
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[39]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[41]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[39]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[41]/div/a
# FIX-2*******************************************************************************
# Repeat Faces and Names Bar & Lounge
# it does not save
# Count 34, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[41]/div/a
# Repeat Faces and Names Bar & Lounge
# it does not save
# Count 35, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[43]/div/a
# FIX-2*******************************************************************************
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[39]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[41]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[39]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[41]/div/a
# FIX-2*******************************************************************************
# Repeat Faces and Names Bar & Lounge
# it does not save
# count  without click 35
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[39]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[41]/div/a
# Count 35, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[41]/div/a
# -------------------------------------------------------------------------------------------------------
# Art Bar
# -------------------------------------------------------------------------------------------------------
# Count 36, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[43]/div/a
# -------------------------------------------------------------------------------------------------------
# Park Bar
# -------------------------------------------------------------------------------------------------------
# Count 37, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[45]/div/a
# FIX-2*******************************************************************************
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[41]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[43]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[41]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[43]/div/a
# FIX-2*******************************************************************************
# Repeat Park Bar
# it does not save
# Count 37, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[43]/div/a
# Repeat Park Bar
# it does not save
# count  without click 38
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[43]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[45]/div/a
# Count 38, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[45]/div/a
# -------------------------------------------------------------------------------------------------------
# Our/New York Bar & Vodka Distillery
# -------------------------------------------------------------------------------------------------------
# Count 39, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[47]/div/a
# -------------------------------------------------------------------------------------------------------
# Sean's Bar & Kitchen
# -------------------------------------------------------------------------------------------------------
# Count 40, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[49]/div/a
# FIX-2*******************************************************************************
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[45]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[47]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[45]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[47]/div/a
# FIX-2*******************************************************************************
# Repeat Sean's Bar & Kitchen
# it does not save
# Count 40, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[47]/div/a
# Repeat Sean's Bar & Kitchen
# it does not save
# count  without click 41
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[47]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[49]/div/a
# Count 41, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[49]/div/a
# -------------------------------------------------------------------------------------------------------
# Thyme Bar
# -------------------------------------------------------------------------------------------------------
# Count 42, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[51]/div/a
# -------------------------------------------------------------------------------------------------------
# S Bar
# -------------------------------------------------------------------------------------------------------
# Count 43, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[53]/div/a
# -------------------------------------------------------------------------------------------------------
# Castell Rooftop Lounge
# -------------------------------------------------------------------------------------------------------
# Count 44, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[55]/div/a
# FIX-2*******************************************************************************
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[51]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[53]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[51]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[53]/div/a
# FIX-2*******************************************************************************
# Repeat Castell Rooftop Lounge
# it does not save
# count  without click 44
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[51]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[53]/div/a
# Count 44, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[53]/div/a
# Repeat Castell Rooftop Lounge
# it does not save
# Count 45, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[55]/div/a
# -------------------------------------------------------------------------------------------------------
# Peak Lounge Bar
# -------------------------------------------------------------------------------------------------------
# Count 46, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[57]/div/a
# FIX-2*******************************************************************************
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[53]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[55]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[53]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[55]/div/a
# FIX-2*******************************************************************************
# Repeat Peak Lounge Bar
# it does not save
# Count 46, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[55]/div/a
# Repeat Peak Lounge Bar
# it does not save
# count  without click 47
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[55]/div/a
# scroll //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[57]/div/a
# Count 47, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[57]/div/a
# -------------------------------------------------------------------------------------------------------
# Mayra tevalan
# -------------------------------------------------------------------------------------------------------
# Count 48, //*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[59]/div/a
